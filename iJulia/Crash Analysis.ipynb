# %%
using ReactionMechanismSimulator
using Sundials
# Out:
# ┌ Info: Precompiling ReactionMechanismSimulator [c2d78dd2-25c4-5b79-bebc-be6c69dd440f]
# └ @ Base loading.jl:1342
# WARNING: Method definition getGibbs(P<:ReactionMechanismSimulator.AbstractThermo, N<:Number) where {N<:Number, P<:ReactionMechanismSimulator.AbstractThermo} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:6 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASApolynomial})() in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:493 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.NASApolynomial}) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:493 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASApolynomial})(Any, Any, Any) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:505 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASApolynomial})(ReactionMechanismSimulator.NASApolynomial) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.NASApolynomial}, ReactionMechanismSimulator.NASApolynomial) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASApolynomial})(ReactionMechanismSimulator.NASApolynomial, Base.AbstractDict{K, V} where V where K) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:572 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASApolynomial})(ReactionMechanismSimulator.NASApolynomial, Tuple{Symbol, Any}...) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:573 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition show(IO, ReactionMechanismSimulator.NASApolynomial) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:581 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @unpack_NASApolynomial(LineNumberNode, Module, Any) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:616 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @pack_NASApolynomial(LineNumberNode, Module) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:603 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition calcHSCpdless(ReactionMechanismSimulator.NASApolynomial, X<:Real) where {X<:Real} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:17 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getHeatCapacity(ReactionMechanismSimulator.NASApolynomial, N<:Number) where {N<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:65 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getEntropy(ReactionMechanismSimulator.NASApolynomial, N<:Number) where {N<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:75 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getEnthalpy(ReactionMechanismSimulator.NASApolynomial, N<:Number) where {N<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:85 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASA{T}})() where {T} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.NASA{T}}) where {T} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASA{T}})(Any, Any) where {T} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:503 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty})(Any, T<:ReactionMechanismSimulator.AbstractThermoUncertainty) where {T<:ReactionMechanismSimulator.AbstractThermoUncertainty} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:526 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty})() in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:545 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty}) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:545 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty})(ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty}, ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty})(ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty, Base.AbstractDict{K, V} where V where K) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:572 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty})(ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty, Tuple{Symbol, Any}...) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:573 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition show(IO, ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:581 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @unpack_NASA(LineNumberNode, Module, Any) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:616 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @pack_NASA(LineNumberNode, Module) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:603 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition selectPoly(ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty, N<:Real) where {N<:Real} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:101 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getHeatCapacity(ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty, N<:Number) where {N<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:114 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getEntropy(ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty, N<:Number) where {N<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:115 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getEnthalpy(ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty, N<:Number) where {N<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:116 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getGibbs(ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty, N<:Number) where {N<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:117 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition calcHSCpdless(ReactionMechanismSimulator.NASA{T} where T<:ReactionMechanismSimulator.AbstractThermoUncertainty, N<:Real) where {N<:Real} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:118 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M}})() where {N, Q, T, P, U, R, M} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M}}) where {N, Q, T, P, U, R, M} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M}})(Any, Any, Any, Any, Any, Any, Any) where {N, Q, T, P, U, R, M} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:503 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N})(N, T, Array{Q, 1}, P, U, R<:Number, M<:ReactionMechanismSimulator.AbstractThermoUncertainty) where {N, Q, T, P, U, R<:Number, M<:ReactionMechanismSimulator.AbstractThermoUncertainty} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:526 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N})() in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:545 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N}) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:545 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N})(ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N}, ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N})(ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N, Base.AbstractDict{K, V} where V where K) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:572 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N})(ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N, Tuple{Symbol, Any}...) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:573 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition show(IO, ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:581 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @unpack_Wilhoit(LineNumberNode, Module, Any) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:616 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @pack_Wilhoit(LineNumberNode, Module) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:603 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getHeatCapacity(ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N, N<:Number) where {N<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:131 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getEnthalpy(ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N, N<:Number) where {N<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:136 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getEntropy(ReactionMechanismSimulator.Wilhoit{N, Q, T, P, U, R, M} where M<:ReactionMechanismSimulator.AbstractThermoUncertainty where R<:Number where U where P where T where Q where N, N<:Number) where {N<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:147 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.ConstantG{B, J}})() where {B, J} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.ConstantG{B, J}}) where {B, J} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.ConstantG{B, J}})(Any, Any) where {B, J} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:503 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number})(B<:Number, J) where {B<:Number, J} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:526 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number})() in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:545 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number}) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:545 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number})(ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number}, ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number})(ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number, Base.AbstractDict{K, V} where V where K) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:572 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number})(ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number, Tuple{Symbol, Any}...) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:573 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition show(IO, ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:581 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @unpack_ConstantG(LineNumberNode, Module, Any) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:616 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @pack_ConstantG(LineNumberNode, Module) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:603 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getGibbs(ReactionMechanismSimulator.ConstantG{B, J} where J where B<:Number, B<:Number) where {B<:Number} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Thermo.jl:158 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q}})() where {N, K, Q} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q}}) where {N, K, Q} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q}})(Any, Any, Any) where {N, K, Q} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:503 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)})(N<:(Array{T, N} where N where T), K<:(Array{T, N} where N where T), Q<:(Array{T, N} where N where T)) where {N<:(Array{T, N} where N where T), K<:(Array{T, N} where N where T), Q<:(Array{T, N} where N where T)} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:526 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)})() in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:545 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)}) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:545 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)})(ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)}, ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)})(ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T), Base.AbstractDict{K, V} where V where K) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:572 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)})(ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T), Tuple{Symbol, Any}...) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:573 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition show(IO, ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:581 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @unpack_Arrheniusvec(LineNumberNode, Module, Any) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:616 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @pack_Arrheniusvec(LineNumberNode, Module) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:603 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)})(T<:(AbstractArray{T, N} where N where T)) where {T<:(AbstractArray{T, N} where N where T)} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:13 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::ReactionMechanismSimulator.Arrheniusvec{N<:(Array{T, N} where N where T), K<:(Array{T, N} where N where T), Q<:(Array{T, N} where N where T)})() in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:24 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Any##kw(Any, ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T)) in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:24 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::ReactionMechanismSimulator.Arrheniusvec{N<:(Array{T, N} where N where T), K<:(Array{T, N} where N where T), Q<:(Array{T, N} where N where T)})(Q<:Real) where {Q<:Real} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:25 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Any##kw(Any, ReactionMechanismSimulator.Arrheniusvec{N, K, Q} where Q<:(Array{T, N} where N where T) where K<:(Array{T, N} where N where T) where N<:(Array{T, N} where N where T), Q<:Real) where {Q<:Real} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:25 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B}})() where {T, Q, S, V, B} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B}}) where {T, Q, S, V, B} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B}})(Any, Any, Any, Any, Any) where {T, Q, S, V, B} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:503 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)})(T<:(AbstractArray{T, N} where N where T), Q<:Real, S<:Real, V<:Real, B<:Real) where {T<:(AbstractArray{T, N} where N where T), Q<:Real, S<:Real, V<:Real, B<:Real} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:526 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)})() in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:545 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)}) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:545 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)})(ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)}, ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:569 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)})(ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T), Base.AbstractDict{K, V} where V where K) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:572 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)})(ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T), Tuple{Symbol, Any}...) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:573 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition show(IO, ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:581 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @unpack_Chebyshevvec(LineNumberNode, Module, Any) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:616 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition @pack_Chebyshevvec(LineNumberNode, Module) in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:603 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)})(T<:(AbstractArray{T, N} where N where T)) where {T<:(AbstractArray{T, N} where N where T)} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:36 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition evalChebyshevPolynomial(ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T), N<:Integer, Q<:Real) where {N<:Integer, Q<:Real} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:49 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition getredtemp(ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T), N<:Real) where {N<:Real} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:71 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
# WARNING: Method definition getredpress(ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T), N<:Real) where {N<:Real} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:80 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::ReactionMechanismSimulator.Chebyshevvec{T<:(AbstractArray{T, N} where N where T), Q<:Real, S<:Real, V<:Real, B<:Real})() in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:89 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Any##kw(Any, ReactionMechanismSimulator.Chebyshevvec{T, Q, S, V, B} where B<:Real where V<:Real where S<:Real where Q<:Real where T<:(AbstractArray{T, N} where N where T)) in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Calculators/Ratevec.jl:89 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Troevec{P, Q, F, L, N, K, R}})() where {P, Q, F, L, N, K, R} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition Type##kw(Any, Type{ReactionMechanismSimulator.Troevec{P, Q, F, L, N, K, R}}) where {P, Q, F, L, N, K, R} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:491 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Troevec{P, Q, F, L, N, K, R}})(Any, Any, Any, Any, Any, Any, Any, Any) where {P, Q, F, L, N, K, R} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:503 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{ReactionMechanismSimulator.Troevec{P, Q, F, L, N, K, R} where R<:ReactionMechanismSimulator.AbstractRateUncertainty where K<:AbstractFloat where N<:Integer where L<:(AbstractArray{T, N} where N where T) where F<:(AbstractArray{T, N} where N where T) where Q<:(AbstractArray{T, N} where N where T) where P<:(AbstractArray{T, N} where N where T)})(Any, Any, P<:(AbstractArray{T, N} where N where T), Q<:(AbstractArray{T, N} where N where T), F<:(AbstractArray{T, N} where N where T), L<:(AbstractArray{T, N} where N where T), Array{Base.Dict{N<:Integer, K<:AbstractFloat}, 1}, R<:ReactionMechanismSimulator.AbstractRateUncertainty) where {P<:(AbstractArray{T, N} where N where T), Q<:(AbstractArray{T, N} where N where T), F<:(AbstractArray{T, N} where N where T), L<:(AbstractArray{T, N} where N where T), N<:Integer, K<:AbstractFloat, R<:ReactionMechanismSimulator.AbstractRateUncertainty} in module ReactionMechanismSimulator at /Users/mattjohnson/.julia/packages/Parameters/MK0O4/src/Parameters.jl:526 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# ...
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:invsqrt2π}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:twoinvπ}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:fourinvπ}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:sqrt2π}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:logπ}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:fourπ}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:log4π}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:invπ}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:halfπ}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:logtwo}) in module IrrationalConstants at irrationals.jl:173 overwritten in module StatsFuns at irrationals.jl:180.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:log2π}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:invsqrt2}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:sqrt4π}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:loghalf}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Base.MPFR.BigFloat})(Base.Irrational{:inv4π}) in module IrrationalConstants at irrationals.jl:180 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:sqrt3}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:sqrtπ}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:twoπ}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:quartπ}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:sqrthalfπ}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:sqrt2}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:inv2π}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:invsqrt2π}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:twoinvπ}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:fourinvπ}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:sqrt2π}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:fourπ}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:logπ}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:invπ}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:halfπ}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:logtwo}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:log2π}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:log4π}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:invsqrt2}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:sqrt4π}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:loghalf}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition (::Type{Float64})(Base.Irrational{:inv4π}) in module IrrationalConstants at irrationals.jl:189 overwritten in module StatsFuns on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# ┌ Warning: PyPlot is using tkagg backend, which is known to cause crashes on MacOS (#410); use the MPLBACKEND environment variable to request a different backend.
# └ @ PyPlot ~/.julia/packages/PyPlot/XaELc/src/init.jl:198
# WARNING: Method definition plotrops(Y<:(ReactionMechanismSimulator.Simulation{Q, W, M, L, G, G2, G3, G4, G5} where G5 where G4 where G3 where G2<:(AbstractArray{T, N} where N where T) where G<:Function where L<:(AbstractArray{T, N} where N where T) where M where W<:ReactionMechanismSimulator.AbstractDomain where Q<:(SciMLBase.AbstractODESolution{T, N, S} where S where N where T)), X<:AbstractString) where {Y<:(ReactionMechanismSimulator.Simulation{Q, W, M, L, G, G2, G3, G4, G5} where G5 where G4 where G3 where G2<:(AbstractArray{T, N} where N where T) where G<:Function where L<:(AbstractArray{T, N} where N where T) where M where W<:ReactionMechanismSimulator.AbstractDomain where Q<:(SciMLBase.AbstractODESolution{T, N, S} where S where N where T)), X<:AbstractString} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Plotting.jl:178 overwritten at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Plotting.jl:226.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition plotrops##kw(Any, typeof(ReactionMechanismSimulator.plotrops), Y<:(ReactionMechanismSimulator.Simulation{Q, W, M, L, G, G2, G3, G4, G5} where G5 where G4 where G3 where G2<:(AbstractArray{T, N} where N where T) where G<:Function where L<:(AbstractArray{T, N} where N where T) where M where W<:ReactionMechanismSimulator.AbstractDomain where Q<:(SciMLBase.AbstractODESolution{T, N, S} where S where N where T)), X<:AbstractString) where {Y<:(ReactionMechanismSimulator.Simulation{Q, W, M, L, G, G2, G3, G4, G5} where G5 where G4 where G3 where G2<:(AbstractArray{T, N} where N where T) where G<:Function where L<:(AbstractArray{T, N} where N where T) where M where W<:ReactionMechanismSimulator.AbstractDomain where Q<:(SciMLBase.AbstractODESolution{T, N, S} where S where N where T)), X<:AbstractString} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Plotting.jl:178 overwritten at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Plotting.jl:226.
#   ** incremental compilation may be fatally broken for this module **
#
# ┌ Warning: Replacing docs for `ReactionMechanismSimulator.plotrops :: Union{Tuple{X}, Tuple{Y}, Tuple{Y, X}} where {Y<:ReactionMechanismSimulator.Simulation, X<:AbstractString}` in module `ReactionMechanismSimulator`
# └ @ Base.Docs docs/Docs.jl:240
# WARNING: Method definition plotrops(Y<:(ReactionMechanismSimulator.Simulation{Q, W, M, L, G, G2, G3, G4, G5} where G5 where G4 where G3 where G2<:(AbstractArray{T, N} where N where T) where G<:Function where L<:(AbstractArray{T, N} where N where T) where M where W<:ReactionMechanismSimulator.AbstractDomain where Q<:(SciMLBase.AbstractODESolution{T, N, S} where S where N where T)), X<:AbstractString) where {Y<:(ReactionMechanismSimulator.Simulation{Q, W, M, L, G, G2, G3, G4, G5} where G5 where G4 where G3 where G2<:(AbstractArray{T, N} where N where T) where G<:Function where L<:(AbstractArray{T, N} where N where T) where M where W<:ReactionMechanismSimulator.AbstractDomain where Q<:(SciMLBase.AbstractODESolution{T, N, S} where S where N where T)), X<:AbstractString} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Plotting.jl:226 overwritten at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Plotting.jl:274.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition plotrops##kw(Any, typeof(ReactionMechanismSimulator.plotrops), Y<:(ReactionMechanismSimulator.Simulation{Q, W, M, L, G, G2, G3, G4, G5} where G5 where G4 where G3 where G2<:(AbstractArray{T, N} where N where T) where G<:Function where L<:(AbstractArray{T, N} where N where T) where M where W<:ReactionMechanismSimulator.AbstractDomain where Q<:(SciMLBase.AbstractODESolution{T, N, S} where S where N where T)), X<:AbstractString) where {Y<:(ReactionMechanismSimulator.Simulation{Q, W, M, L, G, G2, G3, G4, G5} where G5 where G4 where G3 where G2<:(AbstractArray{T, N} where N where T) where G<:Function where L<:(AbstractArray{T, N} where N where T) where M where W<:ReactionMechanismSimulator.AbstractDomain where Q<:(SciMLBase.AbstractODESolution{T, N, S} where S where N where T)), X<:AbstractString} in module ReactionMechanismSimulator at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Plotting.jl:226 overwritten at /Users/mattjohnson/RMGCODE/ReactionMechanismSimulator/src/Plotting.jl:274.
#   ** incremental compilation may be fatally broken for this module **
#
# ┌ Warning: Replacing docs for `ReactionMechanismSimulator.plotrops :: Union{Tuple{X}, Tuple{Y}, Tuple{Y, X}} where {Y<:ReactionMechanismSimulator.Simulation, X<:AbstractString}` in module `ReactionMechanismSimulator`
# └ @ Base.Docs docs/Docs.jl:240
# ┌ Warning: PyPlot is using tkagg backend, which is known to cause crashes on MacOS (#410); use the MPLBACKEND environment variable to request a different backend.
# └ @ PyPlot /Users/mattjohnson/.julia/packages/PyPlot/XaELc/src/init.jl:198

# %%
phaseDict = readinput("../src/testing/superminimal_broken.rms")
# Out:
# [10:53:07] WARNING: not removing hydrogen atom without neighbors
# Dict{Any, Any} with 1 entry:
#   "phase" => Dict{Any, Any}("Species"=>Species[Species{NASA{EmptyThermoUncertai…

# %%
spcs = phaseDict["phase"]["Species"];
rxns = phaseDict["phase"]["Reactions"];

# %%
ig = IdealGas(spcs,rxns;name="gas");
initialconds = Dict(["T"=>1000.0,"P"=>1e5,"H2"=>0.67,"O2"=>0.33]) #Set simulation Initial Temp and Pressure
domain,y0,p = ConstantTPDomain(phase=ig,initialconds=initialconds); #Define the domain (encodes how system thermodynamic properties calculated)
react = Reactor(domain,y0,(0.0,150.11094);p=p); #Create the reactor object

# %%
sol = solve(react.ode,CVODE_BDF(),abstol=1e-20,reltol=1e-12); #solve the ode associated with the reactor
# Out:
# [CVODE ERROR]  CVode
#   At t = 0 and h = 3.88016e-20, the corrector convergence test failed repeatedly or with |h| = hmin.

# %%
sim = Simulation(sol,domain,[],p);

# %%
dmech = analyzecrash(sim)
# Out:
# ReactionMechanismSimulator.DebugMech(ReactionMechanismSimulator.DebugSpecies[ReactionMechanismSimulator.DebugSpecies("HO2", -246949.94307407853, NaN, NaN, 1.0e6, 7), ReactionMechanismSimulator.DebugSpecies("OH", -161664.96169193648, NaN, NaN, 1.0e6, 8), ReactionMechanismSimulator.DebugSpecies("H2O", -448293.20558018977, NaN, NaN, 1.0e6, 10), ReactionMechanismSimulator.DebugSpecies("H2O2", -395008.66142312344, NaN, NaN, 1.0e6, 11)], ReactionMechanismSimulator.DebugReaction[ReactionMechanismSimulator.DebugReaction(ReactionMechanismSimulator.DebugSpecies[ReactionMechanismSimulator.DebugSpecies("OH", -161664.96169193648, 0.0, 0.0, 0.0, 0), ReactionMechanismSimulator.DebugSpecies("H2O2", -395008.66142312344, 0.0, 0.0, 0.0, 0)], ReactionMechanismSimulator.DebugSpecies[ReactionMechanismSimulator.DebugSpecies("HO2", -246949.94307407853, 0.0, 0.0, 0.0, 0), ReactionMechanismSimulator.DebugSpecies("H2O", -448293.20558018977, 0.0, 0.0, 0.0, 0)], "OH+H2O2<=>HO2+H2O", 1.0e6, NaN, NaN, NaN, NaN, 1000.0, 0.0, 11)])

# %%
printcrashreport(dmech)
# Out:
# UndefVarError: printcrashreport not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[16]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116
